# %%
#@title **Create User**
import os
username = "ilya" #@param {type:"string"}
password = "q1qq1q" #@param {type:"string"}

print("Creating User and Setting it up")

# Creat user
os.system(f"useradd -m {username}")

# Add user to sudo group
os.system(f"adduser {username} sudo")

# Set password user to 'root'
os.system(f"echo '{username}:{password}' | sudo chpasswd")

# Change default shell from sh to bash
os.system("sed -i 's/\/bin\/sh/\/bin\/bash/g' /etc/passwd")

print("User Created and Configured")

# %%
! sudo apt-get update
! sudo apt install firefox -y
! sudo apt install xfce4 -y
! sudo apt-get install xfce4 xfce4-terminal -y
! wget -O ud.deb https://dl.google.com/linux/direct/chrome-remote-desktop_current_amd64.deb
! sudo dpkg -i ud.deb
! DISPLAY= /opt/google/chrome-remote-desktop/start-host --code="4/0AeoWuM-hfQHvfLt_E1S-U6gLyvcezewL2k_kpmNrIUPiL0LGW6YPd10occ8S7lXIPD3fYA" --redirect-url="https://remotedesktop.google.com/_/oauthredirect" --name=$(hostname)
